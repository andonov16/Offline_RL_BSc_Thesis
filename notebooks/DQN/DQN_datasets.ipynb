# %%
import pandas as pd

states_rewards_next_states_df = pd.read_parquet('../../data/replay_buffer_episodes/rb_train_next_states_included.parquet')

# %%
state_action_pairs = pd.read_parquet('../../data/replay_buffer_episodes/rb_train.parquet')
print('Train: ', len(state_action_pairs))

state_action_pairs = pd.read_parquet('../../data/replay_buffer_episodes/rb_test.parquet')
print('Test: ', len(state_action_pairs))

state_action_pairs = pd.read_parquet('../../data/replay_buffer_episodes/rb_valid.parquet')
print('Valid: ', len(state_action_pairs))
# Out:
# Train:  801683
# Test:  102013
# Valid:  96304

# %%
state_action_pairs = pd.read_parquet('../../data/final_policy_episodes/fp_train.parquet')
print('Train: ', len(state_action_pairs))

state_action_pairs = pd.read_parquet('../../data/final_policy_episodes/fp_test.parquet')
print('Test: ', len(state_action_pairs))

state_action_pairs = pd.read_parquet('../../data/final_policy_episodes/fp_valid.parquet')
print('Valid: ', len(state_action_pairs))
# Out:
# Train:  804059
# Test:  99075
# Valid:  96866
